# %%
import numpy as np
import os
import sys
from pprint import pprint
from numpy import sin, cos, pi
import numpy.matlib
import random
from matplotlib import pyplot as plt
from shapely.geometry import Polygon, Point
import shapely.affinity as affinity
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from sklearn.model_selection import train_test_split
import pyomo.environ as pyo
import pyomo.gdp as pyg
from pyomo.gdp import *
from scipy.spatial import ConvexHull
#tf.disable_v2_behavior()  # this line is added to allow placeholder() function to work (does not work in tf2)

# %%
physical_devices = tf.config.list_physical_devices('GPU') 
# tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# # Introduction
#
# In this code, we generate a neural network that predicts the trajectory.
#
# We then enforce a constraint on the output set such that we require the transformed (rotated) points to stay outside a certain region (box).
# TODO: Add more content on how
#
# The idea is to repair the layers of the original neural network train in order to ensure the following two cases:
#
# 1. If true predicted points are outside the region (box) that we define, then the predicted points should be close to the true points;
#
# 2. If true predicted points are outside the region (box), then the predicted points should be close to the true points but also be outside the region (box)
# ------------------------------------------------------------------------------------

# %% [markdown]
# ## Create Data
#
# #### Generate Points
#
# We start by geneating the points and their true outputs using the function as shown below.

# %%
x = np.linspace(0,4,200) 
y = np.stack([np.array([np.exp(-0.5*x[i])*np.sin(x[i]),np.exp(-0.7*x[i])*np.cos(x[i])]) + np.random.normal(0,0.005,1) for i in range(x.shape[0])],axis = 0)

# %%
plt.scatter(y[:,0],y[:,1])
plt.show()

# %% [markdown]
# #### Safe Bound
#
# We now add a safe bound. The idea is that we do not want our predicted ouputs to be inside this safe bound. This does not play a role in generating a network, but only for visualization purpose for the repair step.

# %%
poly3 = Polygon([(.45, .1), (.45, .25), (.55, .25), (.55, .1)])

# get the coordinates of the exterior points of the polytope
ex_points = np.array(poly3.exterior.coords)

# get A and b matrices: A*x <= b
hull = ConvexHull(ex_points)
eqs = np.array(hull.equations)
A = eqs[0:eqs.shape[0],0:eqs.shape[1]-1]  
b = -eqs[0:eqs.shape[0],-1]

# %%
x_poly3, y_poly3 = poly3.exterior.xy
plt.scatter(y[:,0],y[:,1])
plt.plot(x_poly3, y_poly3, color='red', alpha=0.7, linewidth=3, solid_capstyle='round', zorder=2, label='Target Set')
plt.ylim(-.2,1.1)
plt.xlim(-.2,0.7)
plt.show()

# %% [markdown]
# #### Training Mini-Batch Generator

# %%
class Batch(object):
    def __init__(self, X_col, Y_col, batch_size_val):
        self.X = X_col
        self.Y = Y_col
        self.size = X_col.shape[0]
        self.train_size = batch_size_val
        self.test_size = self.size - batch_size_val

    def getBatch(self):
        values = range(self.size)
        train_dataset, test_dataset = train_test_split(values, train_size=self.train_size, test_size=self.test_size)
        # indices = np.random.choice(range(self.size), self.batch_size)  # sampling with replacement
        return self.X[train_dataset], self.Y[train_dataset,:], self.X[test_dataset], self.Y[test_dataset,:]
num_pts = x.shape[0]
batch_size = int(0.7 * num_pts)
batch = Batch(x, y, batch_size)

# %% [markdown]
# ## 3-Layer NN

# %% [markdown]
# #### Build 3-Layer NN Model

# %% [markdown]
# Here we setup a 3-layer MLP, with the single hidden layer of ReLU activation and train it with gradient descent optimizer to learn the defined affine transformation from the given data.
# $$
# \min_{\mathbf{W}^0,\mathbf{W}^1,\mathbf{W}^2,\mathbf{b}^0,\mathbf{b}^1,\mathbf{b}^2}~~\frac{1}{2}\sum^{N}_{n=1}|| \mathbf{y}(\mathbf{x}^0_n,\mathbf{W}^0,\mathbf{W}^1,\mathbf{b}^0,\mathbf{b}^1)-\mathbf{t}_n||^2_2
# $$
# $$
# \mathbf{W}^0 \mathbf{x}^0 + \mathbf{b}^0 = \mathbf{h}^0
# $$
# $$
# \mathbf{x}^1 = \mathrm{ReLU} (\mathbf{h}^0)
# $$
# $$
# \mathbf{W}^1 \mathbf{x}^1 + \mathbf{b}^1 = \mathbf{h}^1
# $$
# $$
# \mathbf{x}^2 = \mathrm{ReLU} (\mathbf{h}^1)
# $$
# $$
# \mathbf{W}^2 \mathbf{x}^2 + \mathbf{b}^2 = \mathbf{y}
# $$

# %% [markdown]
# #### Initializing Parameters for MLP Model

# %%
num_input = 1
num_output = 2
num_hidden_0 = 10
num_hidden_1 = 10
architecture = [num_input, num_hidden_0, num_hidden_1, num_output]
starter_learning_rate = 0.0005
regularizer_rate = 0.01

#Create the 3 layers model
# Define Sequential model with 3 layers
model_orig = keras.Sequential(name="3_layer_NN")
model_orig.add(layers.Dense(num_hidden_0,
                            activation="relu",
                            kernel_regularizer = regularizers.l2(regularizer_rate),
                            bias_regularizer = regularizers.l2(regularizer_rate),
                            input_shape=(num_input,),
                            name="layer0"))
#model_orig.add(layers.Dropout(0.01))
model_orig.add(layers.Dense(num_hidden_1,
                            activation="relu",
                            kernel_regularizer = regularizers.l2(regularizer_rate),
                            bias_regularizer = regularizers.l2(regularizer_rate),
                            name="layer1"))
#model_orig.add(layers.Dropout(0.01))
model_orig.add(layers.Dense(num_output,
                            kernel_regularizer = regularizers.l2(regularizer_rate),
                            bias_regularizer = regularizers.l2(regularizer_rate), 
                            name="output"))

model_orig.summary()
# Out:
# Model: "3_layer_NN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer0 (Dense)              (None, 10)                20
#
#  layer1 (Dense)              (None, 10)                110
#
#  output (Dense)              (None, 2)                 22
#
# =================================================================
# Total params: 152
# Trainable params: 152
# Non-trainable params: 0
# _________________________________________________________________
# 2022-02-23 12:05:59.043064: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-23 12:05:59.892881: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5077 MB memory:  -> device: 0, name: Quadro RTX 4000, pci bus id: 0000:bd:00.0, compute capability: 7.5
# 2022-02-23 12:05:59.893464: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 6136 MB memory:  -> device: 1, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:91:00.0, compute capability: 6.1

# %% [markdown]
# ## Train the model

# %%
import tensorflow.keras.backend as kb
#define costum loss function
def keras_SSE_costum(y_actual, y_predicted):
    err = y_actual - y_predicted
    loss_value = kb.sum(kb.square(err))
    return loss_value

# %%
# define loss 
loss = keras.losses.MeanSquaredError(name='MSE')
#loss = keras.losses.MeanSquaredLogarithmicError(name='MSLE')
optimizer = keras.optimizers.SGD(learning_rate = starter_learning_rate, name='SGD')
model_orig.compile(optimizer = optimizer,
                   loss = keras_SSE_costum,
                   metrics=['accuracy'])
x_train, y_train, x_test, y_test = batch.getBatch()

# %%
his = model_orig.fit(x_train, y_train, epochs=10000, use_multiprocessing = True, verbose = 1)
print("Model Accuracy on Test Data Set")
model_orig.evaluate(x_test,  y_test, verbose=2)
# Out:
# Epoch 1/10000
# 5/5 [==============================] - 1s 4ms/step - loss: 14.2016 - accuracy: 0.1929
# Epoch 2/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 6.0235 - accuracy: 0.2357
# Epoch 3/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 4.6063 - accuracy: 0.4286
# Epoch 4/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 4.0156 - accuracy: 0.6143
# Epoch 5/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 3.5947 - accuracy: 0.7929
# Epoch 6/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 3.2800 - accuracy: 0.7429
# Epoch 7/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 3.1732 - accuracy: 0.7429
# Epoch 8/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 2.9837 - accuracy: 0.7429
# Epoch 9/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7983 - accuracy: 0.7429
# Epoch 10/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 2.6468 - accuracy: 0.7429
# Epoch 11/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 2.5356 - accuracy: 0.7429
# Epoch 12/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 2.3740 - accuracy: 0.7429
# Epoch 13/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 2.1612 - accuracy: 0.7429
# Epoch 14/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 2.2668 - accuracy: 0.7429
# Epoch 15/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 2.0192 - accuracy: 0.7429
# Epoch 16/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 2.0575 - accuracy: 0.7429
# Epoch 17/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 2.0620 - accuracy: 0.7429
# Epoch 18/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.9564 - accuracy: 0.7429
# Epoch 19/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 1.8777 - accuracy: 0.7429
# Epoch 20/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.8192 - accuracy: 0.7429
# Epoch 21/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.8687 - accuracy: 0.7429
# Epoch 22/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.7205 - accuracy: 0.7429
# Epoch 23/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.7596 - accuracy: 0.7429
# Epoch 24/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.6507 - accuracy: 0.7429
# Epoch 25/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.7110 - accuracy: 0.7429
# Epoch 26/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 1.6872 - accuracy: 0.7429
# Epoch 27/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.6712 - accuracy: 0.7429
# Epoch 28/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 1.5061 - accuracy: 0.7429
# Epoch 29/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.5259 - accuracy: 0.7429
# Epoch 30/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 1.4941 - accuracy: 0.7429
# Epoch 31/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.5221 - accuracy: 0.7429
# Epoch 32/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 1.5513 - accuracy: 0.7429
# Epoch 33/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.5767 - accuracy: 0.7429
# Epoch 34/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.4864 - accuracy: 0.7429
# Epoch 35/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 1.5585 - accuracy: 0.7429
# Epoch 36/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.5177 - accuracy: 0.7429
# Epoch 37/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.3315 - accuracy: 0.7429
# Epoch 38/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.5103 - accuracy: 0.7429
# Epoch 39/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.5351 - accuracy: 0.7429
# Epoch 40/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.5047 - accuracy: 0.7429
# Epoch 41/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 1.4449 - accuracy: 0.7429
# Epoch 42/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.4101 - accuracy: 0.7429
# Epoch 43/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.4897 - accuracy: 0.7429
# Epoch 44/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 1.4670 - accuracy: 0.7429
# Epoch 45/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.4571 - accuracy: 0.7429
# Epoch 46/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.4090 - accuracy: 0.7429
# Epoch 47/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 1.4442 - accuracy: 0.7429
# Epoch 48/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 1.3823 - accuracy: 0.7429
# Epoch 49/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 1.3842 - accuracy: 0.7429
# Epoch 50/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.3329 - accuracy: 0.7429
# Epoch 51/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.4495 - accuracy: 0.7429
# Epoch 52/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 1.3622 - accuracy: 0.7429
# Epoch 53/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.4291 - accuracy: 0.7429
# Epoch 54/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.4291 - accuracy: 0.7429
# Epoch 55/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.4282 - accuracy: 0.7429
# Epoch 56/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.4330 - accuracy: 0.7429
# Epoch 57/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 1.3440 - accuracy: 0.7429
# Epoch 58/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2545 - accuracy: 0.7429
# Epoch 59/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.4123 - accuracy: 0.7429
# Epoch 60/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.3913 - accuracy: 0.7429
# Epoch 61/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2895 - accuracy: 0.7429
# Epoch 62/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 1.3833 - accuracy: 0.7429
# Epoch 63/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 1.3906 - accuracy: 0.7429
# Epoch 64/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.3611 - accuracy: 0.7429
# Epoch 65/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 1.3720 - accuracy: 0.7429
# Epoch 66/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.3870 - accuracy: 0.7429
# Epoch 67/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.3662 - accuracy: 0.7429
# Epoch 68/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.3547 - accuracy: 0.7429
# Epoch 69/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.3450 - accuracy: 0.7429
# Epoch 70/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.3598 - accuracy: 0.7429
# Epoch 71/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.3265 - accuracy: 0.7429
# Epoch 72/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.3480 - accuracy: 0.7429
# Epoch 73/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.3538 - accuracy: 0.7429
# Epoch 74/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2002 - accuracy: 0.7429
# Epoch 75/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2733 - accuracy: 0.7429
# Epoch 76/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.3259 - accuracy: 0.7429
# Epoch 77/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.3048 - accuracy: 0.7429
# Epoch 78/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2853 - accuracy: 0.7429
# Epoch 79/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.3068 - accuracy: 0.7429
# Epoch 80/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 1.2548 - accuracy: 0.7429
# Epoch 81/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2979 - accuracy: 0.7429
# Epoch 82/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.3129 - accuracy: 0.7429
# Epoch 83/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.3070 - accuracy: 0.7429
# Epoch 84/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 1.3077 - accuracy: 0.7429
# Epoch 85/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 1.2397 - accuracy: 0.7429
# Epoch 86/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2827 - accuracy: 0.7429
# Epoch 87/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2962 - accuracy: 0.7429
# Epoch 88/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2342 - accuracy: 0.7429
# Epoch 89/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2796 - accuracy: 0.7429
# Epoch 90/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2920 - accuracy: 0.7429
# Epoch 91/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 1.2031 - accuracy: 0.7429
# Epoch 92/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 1.2552 - accuracy: 0.7429
# Epoch 93/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.1659 - accuracy: 0.7429
# Epoch 94/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2792 - accuracy: 0.7429
# Epoch 95/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2468 - accuracy: 0.7429
# Epoch 96/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 1.2146 - accuracy: 0.7429
# Epoch 97/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2434 - accuracy: 0.7429
# Epoch 98/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 1.2496 - accuracy: 0.7643
# Epoch 99/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.1697 - accuracy: 0.7643
# Epoch 100/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2609 - accuracy: 0.7714
# Epoch 101/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2529 - accuracy: 0.7714
# Epoch 102/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2163 - accuracy: 0.7714
# Epoch 103/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2097 - accuracy: 0.7714
# Epoch 104/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2171 - accuracy: 0.7786
# Epoch 105/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2338 - accuracy: 0.7857
# Epoch 106/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2025 - accuracy: 0.7857
# Epoch 107/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2244 - accuracy: 0.7857
# Epoch 108/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2138 - accuracy: 0.7929
# Epoch 109/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2235 - accuracy: 0.7929
# Epoch 110/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2197 - accuracy: 0.7929
# Epoch 111/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 1.1936 - accuracy: 0.7929
# Epoch 112/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 1.0763 - accuracy: 0.7929
# Epoch 113/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.1535 - accuracy: 0.7929
# Epoch 114/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.1501 - accuracy: 0.7929
# Epoch 115/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.1368 - accuracy: 0.8000
# Epoch 116/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.1401 - accuracy: 0.8000
# Epoch 117/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.1600 - accuracy: 0.7929
# Epoch 118/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.1310 - accuracy: 0.8071
# Epoch 119/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.1557 - accuracy: 0.8071
# Epoch 120/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.1763 - accuracy: 0.8071
# Epoch 121/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0856 - accuracy: 0.8071
# Epoch 122/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.1107 - accuracy: 0.8071
# Epoch 123/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.1570 - accuracy: 0.8071
# Epoch 124/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 1.1590 - accuracy: 0.8071
# Epoch 125/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0929 - accuracy: 0.8071
# Epoch 126/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0998 - accuracy: 0.8071
# Epoch 127/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.1622 - accuracy: 0.8071
# Epoch 128/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.1221 - accuracy: 0.8071
# Epoch 129/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.1344 - accuracy: 0.8071
# Epoch 130/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 1.0992 - accuracy: 0.8071
# Epoch 131/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.1332 - accuracy: 0.8143
# Epoch 132/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0951 - accuracy: 0.8143
# Epoch 133/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.1122 - accuracy: 0.8143
# Epoch 134/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.1342 - accuracy: 0.8286
# Epoch 135/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 1.0760 - accuracy: 0.8214
# Epoch 136/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0999 - accuracy: 0.8214
# Epoch 137/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0846 - accuracy: 0.8214
# Epoch 138/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0576 - accuracy: 0.8286
# Epoch 139/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.1130 - accuracy: 0.8286
# Epoch 140/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 1.1195 - accuracy: 0.8286
# Epoch 141/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 1.0648 - accuracy: 0.8286
# Epoch 142/10000
# 5/5 [==============================] - 0s 2ms/step - loss: 1.1237 - accuracy: 0.8214
# Epoch 143/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 1.0869 - accuracy: 0.8286
# Epoch 144/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0953 - accuracy: 0.8357
# Epoch 145/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 1.1013 - accuracy: 0.8357
# Epoch 146/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.9920 - accuracy: 0.8357
# Epoch 147/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 1.0895 - accuracy: 0.8357
# Epoch 148/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9752 - accuracy: 0.8357
# Epoch 149/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 1.0347 - accuracy: 0.8357
# Epoch 150/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0779 - accuracy: 0.8357
# Epoch 151/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9932 - accuracy: 0.8357
# Epoch 152/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0683 - accuracy: 0.8429
# Epoch 153/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 1.0715 - accuracy: 0.8429
# Epoch 154/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0311 - accuracy: 0.8429
# Epoch 155/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0447 - accuracy: 0.8429
# Epoch 156/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0601 - accuracy: 0.8429
# Epoch 157/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0542 - accuracy: 0.8429
# Epoch 158/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0275 - accuracy: 0.8429
# Epoch 159/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0280 - accuracy: 0.8429
# Epoch 160/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0472 - accuracy: 0.8429
# Epoch 161/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9663 - accuracy: 0.8429
# Epoch 162/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0263 - accuracy: 0.8429
# Epoch 163/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0307 - accuracy: 0.8429
# Epoch 164/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9634 - accuracy: 0.8500
# Epoch 165/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0170 - accuracy: 0.8500
# Epoch 166/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9830 - accuracy: 0.8500
# Epoch 167/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.9713 - accuracy: 0.8500
# Epoch 168/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0218 - accuracy: 0.8500
# Epoch 169/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0167 - accuracy: 0.8500
# Epoch 170/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0108 - accuracy: 0.8500
# Epoch 171/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 1.0095 - accuracy: 0.8500
# Epoch 172/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9892 - accuracy: 0.8500
# Epoch 173/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.9519 - accuracy: 0.8500
# Epoch 174/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.9834 - accuracy: 0.8500
# Epoch 175/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9624 - accuracy: 0.8571
# Epoch 176/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9948 - accuracy: 0.8500
# Epoch 177/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9370 - accuracy: 0.8571
# Epoch 178/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.9301 - accuracy: 0.8571
# Epoch 179/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.9290 - accuracy: 0.8571
# Epoch 180/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9317 - accuracy: 0.8571
# Epoch 181/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.9796 - accuracy: 0.8643
# Epoch 182/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.9284 - accuracy: 0.8643
# Epoch 183/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.9706 - accuracy: 0.8571
# Epoch 184/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9409 - accuracy: 0.8643
# Epoch 185/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.9662 - accuracy: 0.8643
# Epoch 186/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.9536 - accuracy: 0.8643
# Epoch 187/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9233 - accuracy: 0.8643
# Epoch 188/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9059 - accuracy: 0.8643
# Epoch 189/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9139 - accuracy: 0.8643
# Epoch 190/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.9545 - accuracy: 0.8643
# Epoch 191/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9543 - accuracy: 0.8714
# Epoch 192/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9456 - accuracy: 0.8714
# Epoch 193/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9410 - accuracy: 0.8714
# Epoch 194/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9344 - accuracy: 0.8714
# Epoch 195/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8830 - accuracy: 0.8714
# Epoch 196/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9224 - accuracy: 0.8714
# Epoch 197/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8396 - accuracy: 0.8714
# Epoch 198/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9227 - accuracy: 0.8786
# Epoch 199/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8707 - accuracy: 0.8786
# Epoch 200/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8896 - accuracy: 0.8714
# Epoch 201/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9146 - accuracy: 0.8786
# Epoch 202/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9143 - accuracy: 0.8786
# Epoch 203/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.9085 - accuracy: 0.8786
# Epoch 204/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8449 - accuracy: 0.8786
# Epoch 205/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8193 - accuracy: 0.8857
# Epoch 206/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8877 - accuracy: 0.8857
# Epoch 207/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8940 - accuracy: 0.8857
# Epoch 208/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8959 - accuracy: 0.8857
# Epoch 209/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8359 - accuracy: 0.8857
# Epoch 210/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.8855 - accuracy: 0.8786
# Epoch 211/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8359 - accuracy: 0.8786
# Epoch 212/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8686 - accuracy: 0.8786
# Epoch 213/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8871 - accuracy: 0.8857
# Epoch 214/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8842 - accuracy: 0.8857
# Epoch 215/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8752 - accuracy: 0.8857
# Epoch 216/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8650 - accuracy: 0.8857
# Epoch 217/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8708 - accuracy: 0.8857
# Epoch 218/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.8438 - accuracy: 0.8857
# Epoch 219/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8656 - accuracy: 0.8857
# Epoch 220/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8091 - accuracy: 0.8857
# Epoch 221/10000
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7921 - accuracy: 0.8857
# Epoch 222/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8165 - accuracy: 0.8857
# Epoch 223/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8034 - accuracy: 0.8857
# Epoch 224/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8374 - accuracy: 0.8857
# Epoch 225/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8456 - accuracy: 0.8857
# Epoch 226/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8211 - accuracy: 0.8857
# Epoch 227/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8258 - accuracy: 0.8857
# Epoch 228/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8036 - accuracy: 0.8857
# Epoch 229/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8273 - accuracy: 0.8857
# Epoch 230/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8307 - accuracy: 0.8857
# Epoch 231/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7666 - accuracy: 0.8857
# Epoch 232/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8223 - accuracy: 0.8857
# Epoch 233/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7818 - accuracy: 0.8857
# Epoch 234/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.7738 - accuracy: 0.8786
# Epoch 235/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8003 - accuracy: 0.8786
# Epoch 236/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7885 - accuracy: 0.8786
# Epoch 237/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.7968 - accuracy: 0.8786
# Epoch 238/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8076 - accuracy: 0.8786
# Epoch 239/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7992 - accuracy: 0.8786
# Epoch 240/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8009 - accuracy: 0.8786
# Epoch 241/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.7366 - accuracy: 0.8857
# Epoch 242/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.7192 - accuracy: 0.8786
# Epoch 243/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7903 - accuracy: 0.8786
# Epoch 244/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7818 - accuracy: 0.8786
# Epoch 245/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7836 - accuracy: 0.8786
# Epoch 246/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7385 - accuracy: 0.8786
# Epoch 247/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.7739 - accuracy: 0.8786
# Epoch 248/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7099 - accuracy: 0.8786
# Epoch 249/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.7188 - accuracy: 0.8786
# Epoch 250/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.7677 - accuracy: 0.8786
# Epoch 251/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7670 - accuracy: 0.8786
# Epoch 252/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.7643 - accuracy: 0.8786
# Epoch 253/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.7459 - accuracy: 0.8786
# Epoch 254/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7196 - accuracy: 0.8786
# Epoch 255/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7158 - accuracy: 0.8786
# Epoch 256/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6941 - accuracy: 0.8786
# Epoch 257/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7445 - accuracy: 0.8786
# Epoch 258/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7523 - accuracy: 0.8786
# Epoch 259/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7444 - accuracy: 0.8786
# Epoch 260/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7355 - accuracy: 0.8786
# Epoch 261/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7218 - accuracy: 0.8786
# Epoch 262/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.7330 - accuracy: 0.8786
# Epoch 263/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7136 - accuracy: 0.8786
# Epoch 264/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.7324 - accuracy: 0.8786
# Epoch 265/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6819 - accuracy: 0.8786
# Epoch 266/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7223 - accuracy: 0.8786
# Epoch 267/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7220 - accuracy: 0.8786
# Epoch 268/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6999 - accuracy: 0.8786
# Epoch 269/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7014 - accuracy: 0.8786
# Epoch 270/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7075 - accuracy: 0.8714
# Epoch 271/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7079 - accuracy: 0.8786
# Epoch 272/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6905 - accuracy: 0.8714
# Epoch 273/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6951 - accuracy: 0.8714
# Epoch 274/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6965 - accuracy: 0.8714
# Epoch 275/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6962 - accuracy: 0.8714
# Epoch 276/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6903 - accuracy: 0.8714
# Epoch 277/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6605 - accuracy: 0.8786
# Epoch 278/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6500 - accuracy: 0.8714
# Epoch 279/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6737 - accuracy: 0.8714
# Epoch 280/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6838 - accuracy: 0.8714
# Epoch 281/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.6767 - accuracy: 0.8714
# Epoch 282/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6389 - accuracy: 0.8714
# Epoch 283/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6618 - accuracy: 0.8714
# Epoch 284/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6754 - accuracy: 0.8714
# Epoch 285/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6694 - accuracy: 0.8714
# Epoch 286/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6660 - accuracy: 0.8714
# Epoch 287/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6666 - accuracy: 0.8714
# Epoch 288/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6644 - accuracy: 0.8714
# Epoch 289/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6540 - accuracy: 0.8714
# Epoch 290/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6588 - accuracy: 0.8714
# Epoch 291/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6578 - accuracy: 0.8714
# Epoch 292/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6488 - accuracy: 0.8714
# Epoch 293/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6509 - accuracy: 0.8714
# Epoch 294/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.6437 - accuracy: 0.8714
# Epoch 295/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6251 - accuracy: 0.8714
# Epoch 296/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6408 - accuracy: 0.8714
# Epoch 297/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6424 - accuracy: 0.8714
# Epoch 298/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6424 - accuracy: 0.8714
# Epoch 299/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6387 - accuracy: 0.8643
# Epoch 300/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.6304 - accuracy: 0.8714
# Epoch 301/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5669 - accuracy: 0.8714
# Epoch 302/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.6162 - accuracy: 0.8714
# Epoch 303/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6290 - accuracy: 0.8714
# Epoch 304/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5922 - accuracy: 0.8714
# Epoch 305/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6206 - accuracy: 0.8643
# Epoch 306/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6186 - accuracy: 0.8643
# Epoch 307/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6124 - accuracy: 0.8643
# Epoch 308/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6120 - accuracy: 0.8643
# Epoch 309/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6128 - accuracy: 0.8643
# Epoch 310/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6103 - accuracy: 0.8643
# Epoch 311/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6107 - accuracy: 0.8643
# Epoch 312/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.6032 - accuracy: 0.8643
# Epoch 313/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5984 - accuracy: 0.8643
# Epoch 314/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6010 - accuracy: 0.8643
# Epoch 315/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5850 - accuracy: 0.8643
# Epoch 316/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5606 - accuracy: 0.8643
# Epoch 317/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5903 - accuracy: 0.8643
# Epoch 318/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5906 - accuracy: 0.8643
# Epoch 319/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5862 - accuracy: 0.8643
# Epoch 320/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5867 - accuracy: 0.8643
# Epoch 321/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5509 - accuracy: 0.8643
# Epoch 322/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5521 - accuracy: 0.8643
# Epoch 323/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5776 - accuracy: 0.8643
# Epoch 324/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5769 - accuracy: 0.8643
# Epoch 325/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5624 - accuracy: 0.8643
# Epoch 326/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5613 - accuracy: 0.8643
# Epoch 327/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5697 - accuracy: 0.8643
# Epoch 328/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5229 - accuracy: 0.8643
# Epoch 329/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5521 - accuracy: 0.8643
# Epoch 330/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5547 - accuracy: 0.8643
# Epoch 331/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5592 - accuracy: 0.8643
# Epoch 332/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5350 - accuracy: 0.8643
# Epoch 333/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5586 - accuracy: 0.8643
# Epoch 334/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5565 - accuracy: 0.8643
# Epoch 335/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5528 - accuracy: 0.8643
# Epoch 336/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5506 - accuracy: 0.8643
# Epoch 337/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5498 - accuracy: 0.8643
# Epoch 338/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5500 - accuracy: 0.8643
# Epoch 339/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5412 - accuracy: 0.8643
# Epoch 340/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4944 - accuracy: 0.8643
# Epoch 341/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5422 - accuracy: 0.8643
# Epoch 342/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5424 - accuracy: 0.8643
# Epoch 343/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5393 - accuracy: 0.8643
# Epoch 344/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5332 - accuracy: 0.8643
# Epoch 345/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5073 - accuracy: 0.8643
# Epoch 346/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4995 - accuracy: 0.8643
# Epoch 347/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5284 - accuracy: 0.8643
# Epoch 348/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5210 - accuracy: 0.8643
# Epoch 349/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5163 - accuracy: 0.8571
# Epoch 350/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4830 - accuracy: 0.8643
# Epoch 351/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5103 - accuracy: 0.8571
# Epoch 352/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5094 - accuracy: 0.8571
# Epoch 353/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5157 - accuracy: 0.8571
# Epoch 354/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5113 - accuracy: 0.8571
# Epoch 355/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5145 - accuracy: 0.8571
# Epoch 356/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5147 - accuracy: 0.8571
# Epoch 357/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5086 - accuracy: 0.8571
# Epoch 358/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5029 - accuracy: 0.8571
# Epoch 359/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5052 - accuracy: 0.8571
# Epoch 360/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4818 - accuracy: 0.8571
# Epoch 361/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5046 - accuracy: 0.8571
# Epoch 362/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5027 - accuracy: 0.8571
# Epoch 363/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4999 - accuracy: 0.8571
# Epoch 364/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4801 - accuracy: 0.8571
# Epoch 365/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4935 - accuracy: 0.8571
# Epoch 366/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4954 - accuracy: 0.8571
# Epoch 367/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4934 - accuracy: 0.8571
# Epoch 368/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4672 - accuracy: 0.8571
# Epoch 369/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4897 - accuracy: 0.8571
# Epoch 370/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4897 - accuracy: 0.8571
# Epoch 371/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4850 - accuracy: 0.8571
# Epoch 372/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4869 - accuracy: 0.8571
# Epoch 373/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4831 - accuracy: 0.8571
# Epoch 374/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4840 - accuracy: 0.8571
# Epoch 375/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4810 - accuracy: 0.8571
# Epoch 376/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4460 - accuracy: 0.8571
# Epoch 377/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4548 - accuracy: 0.8571
# Epoch 378/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4773 - accuracy: 0.8571
# Epoch 379/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4757 - accuracy: 0.8571
# Epoch 380/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4736 - accuracy: 0.8571
# Epoch 381/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4626 - accuracy: 0.8571
# Epoch 382/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4321 - accuracy: 0.8571
# Epoch 383/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4462 - accuracy: 0.8571
# Epoch 384/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4662 - accuracy: 0.8571
# Epoch 385/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4665 - accuracy: 0.8571
# Epoch 386/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4639 - accuracy: 0.8571
# Epoch 387/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4623 - accuracy: 0.8571
# Epoch 388/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4618 - accuracy: 0.8643
# Epoch 389/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4523 - accuracy: 0.8571
# Epoch 390/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4568 - accuracy: 0.8571
# Epoch 391/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4547 - accuracy: 0.8714
# Epoch 392/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4544 - accuracy: 0.8643
# Epoch 393/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4064 - accuracy: 0.8643
# Epoch 394/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4472 - accuracy: 0.8714
# Epoch 395/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4348 - accuracy: 0.8571
# Epoch 396/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4462 - accuracy: 0.8643
# Epoch 397/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4491 - accuracy: 0.8643
# Epoch 398/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4250 - accuracy: 0.8714
# Epoch 399/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4464 - accuracy: 0.8714
# Epoch 400/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4365 - accuracy: 0.8714
# Epoch 401/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4278 - accuracy: 0.8643
# Epoch 402/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4401 - accuracy: 0.8714
# Epoch 403/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4336 - accuracy: 0.8643
# Epoch 404/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4227 - accuracy: 0.8714
# Epoch 405/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4383 - accuracy: 0.8714
# Epoch 406/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4360 - accuracy: 0.8714
# Epoch 407/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4359 - accuracy: 0.8714
# Epoch 408/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4107 - accuracy: 0.8714
# Epoch 409/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4202 - accuracy: 0.8714
# Epoch 410/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4334 - accuracy: 0.8714
# Epoch 411/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4288 - accuracy: 0.8714
# Epoch 412/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4295 - accuracy: 0.8786
# Epoch 413/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4100 - accuracy: 0.8714
# Epoch 414/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4283 - accuracy: 0.8714
# Epoch 415/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4109 - accuracy: 0.8786
# Epoch 416/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4203 - accuracy: 0.8714
# Epoch 417/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4223 - accuracy: 0.8786
# Epoch 418/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4210 - accuracy: 0.8786
# Epoch 419/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4219 - accuracy: 0.8857
# Epoch 420/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4197 - accuracy: 0.8857
# Epoch 421/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4209 - accuracy: 0.8714
# Epoch 422/10000
# 5/5 [==============================] - 0s 6ms/step - loss: 0.4076 - accuracy: 0.8857
# Epoch 423/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4061 - accuracy: 0.8857
# Epoch 424/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4106 - accuracy: 0.8786
# Epoch 425/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3957 - accuracy: 0.8786
# Epoch 426/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4069 - accuracy: 0.8786
# Epoch 427/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4126 - accuracy: 0.8857
# Epoch 428/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3920 - accuracy: 0.8857
# Epoch 429/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4081 - accuracy: 0.8857
# Epoch 430/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4084 - accuracy: 0.8857
# Epoch 431/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4091 - accuracy: 0.8929
# Epoch 432/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4079 - accuracy: 0.8929
# Epoch 433/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4017 - accuracy: 0.8857
# Epoch 434/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3843 - accuracy: 0.8929
# Epoch 435/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4056 - accuracy: 0.8857
# Epoch 436/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4041 - accuracy: 0.8929
# Epoch 437/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4044 - accuracy: 0.8929
# Epoch 438/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4031 - accuracy: 0.8786
# Epoch 439/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4009 - accuracy: 0.8929
# Epoch 440/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3997 - accuracy: 0.8857
# Epoch 441/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3990 - accuracy: 0.9000
# Epoch 442/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3920 - accuracy: 0.8929
# Epoch 443/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3965 - accuracy: 0.8929
# Epoch 444/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3943 - accuracy: 0.8929
# Epoch 445/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3952 - accuracy: 0.8857
# Epoch 446/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3882 - accuracy: 0.9000
# Epoch 447/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3938 - accuracy: 0.9000
# Epoch 448/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3937 - accuracy: 0.9000
# Epoch 449/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3920 - accuracy: 0.9000
# Epoch 450/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3702 - accuracy: 0.9000
# Epoch 451/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3904 - accuracy: 0.9000
# Epoch 452/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3903 - accuracy: 0.9000
# Epoch 453/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3890 - accuracy: 0.9000
# Epoch 454/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3876 - accuracy: 0.9000
# Epoch 455/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3873 - accuracy: 0.9000
# Epoch 456/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3723 - accuracy: 0.9000
# Epoch 457/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3794 - accuracy: 0.9000
# Epoch 458/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3853 - accuracy: 0.9000
# Epoch 459/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3680 - accuracy: 0.9000
# Epoch 460/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3834 - accuracy: 0.9000
# Epoch 461/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3765 - accuracy: 0.9000
# Epoch 462/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3649 - accuracy: 0.9000
# Epoch 463/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3645 - accuracy: 0.9000
# Epoch 464/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3504 - accuracy: 0.9000
# Epoch 465/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3740 - accuracy: 0.9000
# Epoch 466/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3782 - accuracy: 0.9000
# Epoch 467/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3788 - accuracy: 0.9071
# Epoch 468/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3757 - accuracy: 0.9000
# Epoch 469/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3747 - accuracy: 0.9071
# Epoch 470/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3743 - accuracy: 0.9000
# Epoch 471/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3631 - accuracy: 0.9000
# Epoch 472/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3748 - accuracy: 0.9000
# Epoch 473/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3583 - accuracy: 0.9071
# Epoch 474/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3555 - accuracy: 0.9071
# Epoch 475/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3741 - accuracy: 0.9000
# Epoch 476/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3657 - accuracy: 0.9000
# Epoch 477/10000
# ...
# Epoch 9846/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1300 - accuracy: 0.9714
# Epoch 9847/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1304 - accuracy: 0.9786
# Epoch 9848/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1304 - accuracy: 0.9786
# Epoch 9849/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1304 - accuracy: 0.9786
# Epoch 9850/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1305 - accuracy: 0.9786
# Epoch 9851/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1304 - accuracy: 0.9786
# Epoch 9852/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1305 - accuracy: 0.9786
# Epoch 9853/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1304 - accuracy: 0.9786
# Epoch 9854/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1302 - accuracy: 0.9786
# Epoch 9855/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1297 - accuracy: 0.9786
# Epoch 9856/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1303 - accuracy: 0.9786
# Epoch 9857/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1306 - accuracy: 0.9714
# Epoch 9858/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1305 - accuracy: 0.9714
# Epoch 9859/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1302 - accuracy: 0.9714
# Epoch 9860/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1299 - accuracy: 0.9714
# Epoch 9861/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1298 - accuracy: 0.9786
# Epoch 9862/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1301 - accuracy: 0.9786
# Epoch 9863/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1303 - accuracy: 0.9786
# Epoch 9864/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1303 - accuracy: 0.9714
# Epoch 9865/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1300 - accuracy: 0.9786
# Epoch 9866/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1303 - accuracy: 0.9786
# Epoch 9867/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1303 - accuracy: 0.9786
# Epoch 9868/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1303 - accuracy: 0.9786
# Epoch 9869/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1293 - accuracy: 0.9786
# Epoch 9870/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1298 - accuracy: 0.9786
# Epoch 9871/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1302 - accuracy: 0.9786
# Epoch 9872/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1299 - accuracy: 0.9786
# Epoch 9873/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1303 - accuracy: 0.9714
# Epoch 9874/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1302 - accuracy: 0.9786
# Epoch 9875/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1302 - accuracy: 0.9786
# Epoch 9876/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1300 - accuracy: 0.9786
# Epoch 9877/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1303 - accuracy: 0.9786
# Epoch 9878/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1302 - accuracy: 0.9786
# Epoch 9879/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1299 - accuracy: 0.9786
# Epoch 9880/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1298 - accuracy: 0.9786
# Epoch 9881/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1302 - accuracy: 0.9786
# Epoch 9882/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1302 - accuracy: 0.9786
# Epoch 9883/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1296 - accuracy: 0.9786
# Epoch 9884/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1303 - accuracy: 0.9786
# Epoch 9885/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1301 - accuracy: 0.9786
# Epoch 9886/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1302 - accuracy: 0.9714
# Epoch 9887/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1302 - accuracy: 0.9786
# Epoch 9888/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1302 - accuracy: 0.9786
# Epoch 9889/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1297 - accuracy: 0.9786
# Epoch 9890/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1301 - accuracy: 0.9786
# Epoch 9891/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1301 - accuracy: 0.9786
# Epoch 9892/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1296 - accuracy: 0.9786
# Epoch 9893/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1298 - accuracy: 0.9786
# Epoch 9894/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1301 - accuracy: 0.9786
# Epoch 9895/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1302 - accuracy: 0.9786
# Epoch 9896/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1305 - accuracy: 0.9714
# Epoch 9897/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1302 - accuracy: 0.9786
# Epoch 9898/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1301 - accuracy: 0.9786
# Epoch 9899/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1299 - accuracy: 0.9786
# Epoch 9900/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1296 - accuracy: 0.9786
# Epoch 9901/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1300 - accuracy: 0.9786
# Epoch 9902/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1299 - accuracy: 0.9786
# Epoch 9903/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1302 - accuracy: 0.9786
# Epoch 9904/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1300 - accuracy: 0.9786
# Epoch 9905/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1297 - accuracy: 0.9786
# Epoch 9906/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1299 - accuracy: 0.9786
# Epoch 9907/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1304 - accuracy: 0.9786
# Epoch 9908/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1302 - accuracy: 0.9786
# Epoch 9909/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1299 - accuracy: 0.9786
# Epoch 9910/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1302 - accuracy: 0.9786
# Epoch 9911/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1302 - accuracy: 0.9786
# Epoch 9912/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1294 - accuracy: 0.9786
# Epoch 9913/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1301 - accuracy: 0.9786
# Epoch 9914/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1298 - accuracy: 0.9786
# Epoch 9915/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1301 - accuracy: 0.9786
# Epoch 9916/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1292 - accuracy: 0.9786
# Epoch 9917/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1296 - accuracy: 0.9786
# Epoch 9918/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1301 - accuracy: 0.9786
# Epoch 9919/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1300 - accuracy: 0.9786
# Epoch 9920/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1289 - accuracy: 0.9786
# Epoch 9921/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1299 - accuracy: 0.9786
# Epoch 9922/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1301 - accuracy: 0.9786
# Epoch 9923/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1302 - accuracy: 0.9786
# Epoch 9924/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1298 - accuracy: 0.9786
# Epoch 9925/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1300 - accuracy: 0.9786
# Epoch 9926/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1300 - accuracy: 0.9786
# Epoch 9927/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1300 - accuracy: 0.9786
# Epoch 9928/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1302 - accuracy: 0.9714
# Epoch 9929/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1298 - accuracy: 0.9714
# Epoch 9930/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1298 - accuracy: 0.9786
# Epoch 9931/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1299 - accuracy: 0.9786
# Epoch 9932/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1292 - accuracy: 0.9786
# Epoch 9933/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1299 - accuracy: 0.9786
# Epoch 9934/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1298 - accuracy: 0.9786
# Epoch 9935/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1301 - accuracy: 0.9714
# Epoch 9936/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1298 - accuracy: 0.9786
# Epoch 9937/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1296 - accuracy: 0.9786
# Epoch 9938/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1302 - accuracy: 0.9786
# Epoch 9939/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1299 - accuracy: 0.9786
# Epoch 9940/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1297 - accuracy: 0.9786
# Epoch 9941/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1297 - accuracy: 0.9786
# Epoch 9942/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1300 - accuracy: 0.9786
# Epoch 9943/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1301 - accuracy: 0.9786
# Epoch 9944/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1300 - accuracy: 0.9786
# Epoch 9945/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1294 - accuracy: 0.9786
# Epoch 9946/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1298 - accuracy: 0.9786
# Epoch 9947/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1296 - accuracy: 0.9786
# Epoch 9948/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1299 - accuracy: 0.9786
# Epoch 9949/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1299 - accuracy: 0.9714
# Epoch 9950/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1294 - accuracy: 0.9786
# Epoch 9951/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1299 - accuracy: 0.9786
# Epoch 9952/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1299 - accuracy: 0.9714
# Epoch 9953/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1297 - accuracy: 0.9786
# Epoch 9954/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1299 - accuracy: 0.9714
# Epoch 9955/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1300 - accuracy: 0.9786
# Epoch 9956/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1299 - accuracy: 0.9786
# Epoch 9957/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1296 - accuracy: 0.9786
# Epoch 9958/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1298 - accuracy: 0.9786
# Epoch 9959/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1299 - accuracy: 0.9786
# Epoch 9960/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1295 - accuracy: 0.9786
# Epoch 9961/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1293 - accuracy: 0.9786
# Epoch 9962/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1287 - accuracy: 0.9714
# Epoch 9963/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1298 - accuracy: 0.9786
# Epoch 9964/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1296 - accuracy: 0.9786
# Epoch 9965/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1296 - accuracy: 0.9786
# Epoch 9966/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1295 - accuracy: 0.9786
# Epoch 9967/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1294 - accuracy: 0.9786
# Epoch 9968/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1294 - accuracy: 0.9786
# Epoch 9969/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1296 - accuracy: 0.9857
# Epoch 9970/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1297 - accuracy: 0.9714
# Epoch 9971/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1299 - accuracy: 0.9786
# Epoch 9972/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1297 - accuracy: 0.9786
# Epoch 9973/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1296 - accuracy: 0.9786
# Epoch 9974/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1298 - accuracy: 0.9786
# Epoch 9975/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1295 - accuracy: 0.9714
# Epoch 9976/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1294 - accuracy: 0.9714
# Epoch 9977/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1290 - accuracy: 0.9786
# Epoch 9978/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1297 - accuracy: 0.9786
# Epoch 9979/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1297 - accuracy: 0.9786
# Epoch 9980/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1296 - accuracy: 0.9786
# Epoch 9981/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1297 - accuracy: 0.9786
# Epoch 9982/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1297 - accuracy: 0.9857
# Epoch 9983/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1298 - accuracy: 0.9786
# Epoch 9984/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1296 - accuracy: 0.9786
# Epoch 9985/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1290 - accuracy: 0.9786
# Epoch 9986/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1296 - accuracy: 0.9786
# Epoch 9987/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1298 - accuracy: 0.9786
# Epoch 9988/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1295 - accuracy: 0.9786
# Epoch 9989/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1295 - accuracy: 0.9786
# Epoch 9990/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1290 - accuracy: 0.9786
# Epoch 9991/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1296 - accuracy: 0.9786
# Epoch 9992/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1296 - accuracy: 0.9786
# Epoch 9993/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1296 - accuracy: 0.9786
# Epoch 9994/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1298 - accuracy: 0.9786
# Epoch 9995/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1295 - accuracy: 0.9786
# Epoch 9996/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1297 - accuracy: 0.9786
# Epoch 9997/10000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1295 - accuracy: 0.9786
# Epoch 9998/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1297 - accuracy: 0.9786
# Epoch 9999/10000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1297 - accuracy: 0.9786
# Epoch 10000/10000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1296 - accuracy: 0.9786
# Model Accuracy on Test Data Set
# 2/2 - 0s - loss: 0.1308 - accuracy: 1.0000 - 116ms/epoch - 58ms/step
# [0.13080143928527832, 1.0]

# %% [markdown]
# #### Plot Loss Function

# %%
results_train_loss = his.history['loss']
plt.plot(results_train_loss, color='red')
plt.title('Loss Function Output')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %% [markdown]
# #### Plot Trained Model Ouput

# %%
def plot_model(model, x_true, y_true, arg):
    y_predict = model_orig.predict(x_true)
    
    ## training output
    plt.plot(y_true[:,0], y_true[:,1], 'ro', label='Original Samples')

    ## predicted output
    plt.plot(y_predict[:,0], y_predict[:,1], 'ko', label='Predicted Output')
    plt.title(arg)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend(loc="upper left")
    plt.show()
    return y_predict

y_predict_train = plot_model(model_orig, x_train, y_train, arg='Trained Model - Training Data')
y_predict_test = plot_model(model_orig, x_test, y_test, arg='Trained Model - Testing Data')

# %%
import os

print(os.getcwd())
from keras.utils.generic_utils import get_custom_objects
get_custom_objects().update({"keras_SSE_costum": keras_SSE_costum})
model_orig.save('forward_kinematics_original_model', os.getcwd())

import pickle

with open(os.getcwd() + "/forward_kinematics_io_dataset.pickle", "wb") as data:
    pickle.dump([x_train, y_train, x_test, y_test], data)
# Out:
# /home/local/ASUAD/tkhandai/NNRepLayer/NNRepLayer/demos/Forward Kinematics Demo
# 2022-02-23 12:10:59.479080: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: forward_kinematics_original_model/assets
